# %%
import pandas as pd
import numpy as np
# Out:
#                                               image_path  Angioectasia  \
# 0      validation\Angioectasia\KID\angioectasia-P0-3.jpg      0.004185
# 1      validation\Angioectasia\KID\angioectasia-P0-4.jpg      0.004542
# 2      validation\Angioectasia\KID\angioectasia-P0-6.jpg      0.000918
# 3      validation\Angioectasia\KID\angioectasia-P1-4.jpg      0.002391
# 4      validation\Angioectasia\KID\angioectasia-P1-5.jpg      0.003380
# ...                                                  ...           ...
# 16127               validation\Worms\AIIMS\worm3_306.jpg      0.002450
# 16128               validation\Worms\AIIMS\worm3_316.jpg      0.000607
# 16129               validation\Worms\AIIMS\worm3_366.jpg      0.000021
# 16130               validation\Worms\AIIMS\worm3_396.jpg      0.002453
# 16131               validation\Worms\AIIMS\worm3_500.jpg      0.008006
#
#        Bleeding   Erosion  Erythema  Foreign Body  Lymphangiectasia    Normal  \
# ...

# %%
df = pd.read_excel('validation_excel.xlsx', sheet_name='Sheet1')

# %%
df = df.drop(columns=['predicted_class'])
df.insert(1, 'dataset', df['image_path'].apply(lambda x: x.split('\\')[2]))

# %%
df.head()
# Out:
#                                           image_path dataset  Angioectasia  \
# 0  validation\Angioectasia\KID\angioectasia-P0-3.jpg     KID      0.004185
# 1  validation\Angioectasia\KID\angioectasia-P0-4.jpg     KID      0.004542
# 2  validation\Angioectasia\KID\angioectasia-P0-6.jpg     KID      0.000918
# 3  validation\Angioectasia\KID\angioectasia-P1-4.jpg     KID      0.002391
# 4  validation\Angioectasia\KID\angioectasia-P1-5.jpg     KID      0.003380
#
#    Bleeding   Erosion  Erythema  Foreign Body  Lymphangiectasia    Normal  \
# 0  0.486679  0.088094  0.315842      0.028344          0.000429  0.004543
# 1  0.197006  0.134947  0.318114      0.152385          0.004182  0.013132
# 2  0.873563  0.022302  0.085260      0.004820          0.000020  0.000755
# 3  0.622612  0.063017  0.263755      0.007502          0.000041  0.001120
# 4  0.017781  0.229323  0.362699      0.015730          0.000705  0.011372
#
#       Polyp     Ulcer     Worms
# 0  0.071805  0.000047  0.000034
# ...

# %%
df.to_excel('validation_excel2.xlsx', index=False)
